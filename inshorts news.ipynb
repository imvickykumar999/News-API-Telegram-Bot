# %%
import requests
from bs4 import BeautifulSoup as bs

link = 'https://inshorts.com/en/read'
req = requests.get(link)

soup = bs(req.content, 'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#   <meta charset="utf-8"/>
#   <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
box = soup.findAll('div', attrs = {'class':'news-card z-depth-1'})
box[0]
# Out:
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#   <span content="" itemid="https://inshorts.com/en/news/choreographerdirector-remo-dsouza-suffers-heart-attack-aged-46-hospitalised-1607688741388" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
#   <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#     <span content="Daisy Mowke" itemprop="name"></span>
#   </span>
#   <span content="Choreographer-director Remo D'souza suffers heart attack aged 46, hospitalised" itemprop="description"></span>
#   <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#     <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/12_dec/11_fri/img_1607686634767_42.jpg?" itemprop="url"/>
#     <meta content="864" itemprop="width"/>
#     <meta content="483" itemprop="height"/>
#   </span>
# ...

# %%
img = box[0].find('div', attrs = {'class':'news-card-image'})
img
# Out:
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/12_dec/11_fri/img_1607686634767_42.jpg?')">
#   </div>

# %%
img_link = img['style'].split("'")[1]
print(img_link)

from IPython.display import Image, display
display(Image(url = img_link, width = 300))
# Out:
# https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/12_dec/11_fri/img_1607686634767_42.jpg?
# <img src="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/12_dec/11_fri/img_1607686634767_42.jpg?" width="300"/>

# %%
head = box[0].find('span', attrs = {'itemprop':'headline'}).text
head
# Out:
# "Choreographer-director Remo D'souza suffers heart attack aged 46, hospitalised"

# %%
time = box[0].find('span', attrs = {'class':'time'})['content'][:10]
time
# Out:
# '2020-12-11'

# %%
body = box[0].find('div', attrs = {'itemprop':'articleBody'}).text
body
# Out:
# 'Choreographer-director Remo D\'souza has suffered a heart attack and is currently admitted in Kokilaben Hospital in Mumbai. His wife Lizelle D\'souza told Indian Express, "It was a blockage. Doctors have done angiography...Please pray." The 46-year-old, who last directed the film \'Street Dancer 3D\', is said to be stable.\n\n\n'

# %%
read_more = box[0].find('a', attrs = {'class':'source'})['href']
print(read_more)
# Out:
# https://indianexpress.com/article/entertainment/bollywood/remo-dsouza-suffers-after-heart-attack-in-icu-7101070/lite/?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts

# %%
import requests
from bs4 import BeautifulSoup as bs
from IPython.display import Image, display

link = 'https://inshorts.com/en/read'
req = requests.get(link)

soup = bs(req.content, 'html5lib')
box = soup.findAll('div', attrs = {'class':'news-card z-depth-1'})

for i in range(len(box)):
    print('HEADING : ', box[i].find('span', attrs = {'itemprop':'headline'}).text)
    print('TIME : ', box[i].find('span', attrs = {'class':'time'})['content'][:10])
    
    img = box[i].find('div', attrs = {'class':'news-card-image'})
    img_link = img['style'].split("'")[1]
    display(Image(url = img_link, width = 300))
    
    print('BODY : ', box[i].find('div', attrs = {'itemprop':'articleBody'}).text, end='\n\n')
    try:
        print('Read More : ', box[i].find('a', attrs = {'class':'source'})['href'])
    except:
        pass
    print('_'*100, end='\n\n')
# Out:
# HEADING :  Choreographer-director Remo D'souza suffers heart attack aged 46, hospitalised
# TIME :  2020-12-11
# <img src="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/12_dec/11_fri/img_1607686634767_42.jpg?" width="300"/>
# BODY :  Choreographer-director Remo D'souza has suffered a heart attack and is currently admitted in Kokilaben Hospital in Mumbai. His wife Lizelle D'souza told Indian Express, "It was a blockage. Doctors have done angiography...Please pray." The 46-year-old, who last directed the film 'Street Dancer 3D', is said to be stable.
#
#
#
#
# Read More :  https://indianexpress.com/article/entertainment/bollywood/remo-dsouza-suffers-after-heart-attack-in-icu-7101070/lite/?utm_campaign=fullarticle&utm_medium=referral&utm_source=inshorts
# ____________________________________________________________________________________________________
#
# HEADING :  Maharashtra govt employees asked to not wear jeans or t-shirt in offices
# TIME :  2020-12-11
# ...

# %%
import urllib.request
from PIL import Image
url = box[4].find('div', attrs = {'class':'news-card-image'})['style'].split("'")[1]
image = Image.open(urllib.request.urlopen(url))
width, height = image.size
print (width,height)
# Out:
# 1080 600
